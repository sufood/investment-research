# %% [markdown]
#                                             PROJECT REPORT ON
#
#                                             “INDIAN RAILWAYS”
#
#
#
#                                          BACHELOR OF TECHNOLOGY
#
#                                          INFORMATION TECHNOLOGY
#                                                   (IT)
#
#                                               SEMESTER VII
#                                                (2018-19)
#
#
#                                                   SUBMITTED:
#                    IN PARTIAL FULFILMENT OF THE REQUIREMENT OF THE INDUSTRIAL TRAINING
#
#
#                                                   SUMBITTED BY:
#                                   1.	TANIMA SARKHEL -18700215057
#                                   2.	NOUREEN SULTANA -18700215027
#                                   3.	AKASH PAUL -18700215005
#                                   4.	PRONAY SAHA -18700215031
#
#
#
#                                                   SUBMITTED ON:
#                                                    14.07.2018
#
#
#
#                                      TECHNO INTERNATIONAL, NEWTOWN
#                           (FORMERLY KNOWN AS TECHNO INDIA COLLEGE OF TECHNOLOGY)
#
#
#
#                                               STUDENT UNDERTAKING
#
#
#
# We, the students of B.tech, have been undertaking that this is my original work and have never been submitted elsewhere. All the work and surveys are done by me in the guidance of our mentors.
#
#
# PROJECTS GUIDE:
# ANIRBAN DEY
#
#
#
#
#                                                 ACKNOWLEDGEMENT
#
#
# I, hereby, express my heartiest gratitude to all sources who have contributed to the making of this project. I oblige thanks to all those who have supported, provided their valuable guidance and helped for the accomplishment of this project. I also extent my hearty thanks to my family, friends, college teachers and all the well-wishers.
#
# I would like to thank my project guide, ANIRBAN DEY,for his guidance and timely suggestions and the information provided by him on this particular topic.
#
# It is a matter of outmost pleasure to express my indebt and deep sense of gratitude to various person who extended their maximum help to supply the necessary information for the present thesis, which became available of the most selfless cooperation.
#
# Above all, my sincere gratitude to the “MAULANA ABUL KALAM AZAD OF TECHNOLOGY (MAKAUT)”, for which this project is given consideration and was done with utmost seriousness.
#
#
#
#
#                                            SCOPE OF THE PROJECT
#
#
# Data Science / Analytics is all about finding valuable insights from the given dataset. In short, finding answers that could help business. In this project, we will see how to get started with Data Analysis in Python. Since usually such projects are based on in-built datasets like iris, it becomes harder for the learner to connect with the analysis and hence learning becomes difficult. To overcome this, the dataset that we use in this notebook is INDIAN_RAILWAYS Dataset posted on Datasets sourced from clipsheet. INDIAN RAILWAYS is one of the important issues of our day-to-day life. Analysis and Visualization of the TIME TABLE of INDIAN RAILWAYS can make access to the Schedules more convenient.
#
#
#                                       SYSTEM AND SOFTWARE REQUIREMENTS
#
# •	Processors: Intel Atom® processor or Intel® Core™ i3 processor
# •	Disk space: 2 GB
# •	Operating systems: Windows® 10
# •	Python* versions: 3.6.X
# •	Included development tools: conda*, conda-env, Jupyter Notebook* (IPython)
# •	Compatible tools: Microsoft Visual Studio*, PyCharm*
# •	Included Python packages: NumPy, pandas, Matplotlib, Sea-born
#
#
#
# Software
# •	Windows: Python 3.6.2, PIP and NumPy 1.13.1, scikit-learn 0.18.2
# •	Intel® Distribution for Python* 2018
#
#
#
#
#
#                                                CONCLUSION
#
#
# With that, we’ve come to the end of this project and as we might have noticed, it just took one line to almost many of the above questions to answers. That tells us two things: Python Expressions are very crispy in terms of its syntax and the second thing is, it doesn’t need to be tens and hundreds of line to bring out a valuable insight — just a few lines could do the magic — If you’re asking the right question!
